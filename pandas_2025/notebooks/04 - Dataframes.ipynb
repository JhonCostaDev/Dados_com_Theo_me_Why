# %%
import pandas as pd
file_path = '/content/drive/MyDrive/Pandas_2025/data/clientes.csv'

# %%
df = pd.read_csv(file_path)
df
# Out:
#                                  idCliente  flEmail  flTwitch  flYouTube  \
# 0     000ff655-fa9f-4baa-a108-47f581ec52a1        0         0          0
# 1     001749bd-37b5-4b1e-8111-f9fbba90f530        0         0          0
# 2     0019bb9e-26d4-4ebf-8727-fc911ea28a92        0         0          0
# 3     0033b737-8235-4c0f-9801-dc4ca185af00        0         1          0
# 4     00684343-40b5-4ce7-b2e8-71a5340973bf        0         0          0
# ...                                    ...      ...       ...        ...
# 2431  fecbdf63-3bf4-44e5-8b1a-0acc9d963603        0         0          0
# 2432  ff07d926-f09e-420b-bebf-3dba02ae5dff        0         1          0
# 2433  ff1ceaef-650c-422b-bdc3-6984e29e7aa5        0         0          0
# 2434  ff2cabd3-3316-4b3f-8494-c25f95e90524        0         1          0
# 2435  ff4909ad-4e52-4767-a6fc-0fbd76e37857        0         0          0
#
#       flBlueSky  flInstagram  qtdePontos                dtCriacao  \
# ...

# %%
# Resumo de informacoes do dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2436 entries, 0 to 2435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   idCliente      2436 non-null   object
#  1   flEmail        2436 non-null   int64
#  2   flTwitch       2436 non-null   int64
#  3   flYouTube      2436 non-null   int64
#  4   flBlueSky      2436 non-null   int64
#  5   flInstagram    2436 non-null   int64
#  6   qtdePontos     2436 non-null   int64
#  7   dtCriacao      834 non-null    object
#  8   dtAtualizacao  834 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 171.4+ KB

# %%
# Resumo de informacoes do dataset
df.info(memory_usage='deep') # tamanho do dataset em memoria
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2436 entries, 0 to 2435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   idCliente      2436 non-null   object
#  1   flEmail        2436 non-null   int64
#  2   flTwitch       2436 non-null   int64
#  3   flYouTube      2436 non-null   int64
#  4   flBlueSky      2436 non-null   int64
#  5   flInstagram    2436 non-null   int64
#  6   qtdePontos     2436 non-null   int64
#  7   dtCriacao      834 non-null    object
#  8   dtAtualizacao  834 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 566.0 KB

# %%
# Exibir as 5 primeiras linhas
df.head()
# Out:
#                               idCliente  flEmail  flTwitch  flYouTube  \
# 0  000ff655-fa9f-4baa-a108-47f581ec52a1        0         0          0
# 1  001749bd-37b5-4b1e-8111-f9fbba90f530        0         0          0
# 2  0019bb9e-26d4-4ebf-8727-fc911ea28a92        0         0          0
# 3  0033b737-8235-4c0f-9801-dc4ca185af00        0         1          0
# 4  00684343-40b5-4ce7-b2e8-71a5340973bf        0         0          0
#
#    flBlueSky  flInstagram  qtdePontos                dtCriacao  \
# 0          0            0         686                      NaN
# 1          0            0          50                      NaN
# 2          0            0           2                      NaN
# 3          0            0        1090  0000-00-00 00:00:00.000
# 4          0            0           0                      NaN
#
#              dtAtualizacao
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  2025-02-19 12:48:24.632
# ...

# %%
# Exibir as 5 ultimas
df.tail()
# Out:
#                                  idCliente  flEmail  flTwitch  flYouTube  \
# 2431  fecbdf63-3bf4-44e5-8b1a-0acc9d963603        0         0          0
# 2432  ff07d926-f09e-420b-bebf-3dba02ae5dff        0         1          0
# 2433  ff1ceaef-650c-422b-bdc3-6984e29e7aa5        0         0          0
# 2434  ff2cabd3-3316-4b3f-8494-c25f95e90524        0         1          0
# 2435  ff4909ad-4e52-4767-a6fc-0fbd76e37857        0         0          0
#
#       flBlueSky  flInstagram  qtdePontos                dtCriacao  \
# 2431          0            0         111                      NaN
# 2432          0            0          54  2025-01-21 11:49:58.172
# 2433          0            0         162                      NaN
# 2434          0            0          57  2025-02-10 11:12:30.631
# 2435          0            0          50                      NaN
#
#                 dtAtualizacao
# 2431                      NaN
# 2432  2025-02-28 11:55:04.999
# 2433                      NaN
# ...

# %%
# Exibir uma amostra aleatoria
df.sample(10)
# Out:
#                                  idCliente  flEmail  flTwitch  flYouTube  \
# 620   3c7a3611-03b7-488b-864b-23ba2520104f        0         0          0
# 744   4a015b48-0f74-465f-ba26-0a58c57a8008        0         0          0
# 1446  94c32ecb-6948-4ca1-b4f0-13cf49859bc7        0         1          0
# 2146  deaa5069-5ba5-46c1-aa1f-dc7ed4e66c55        0         0          0
# 45    03f9edbb-7420-4f36-9a24-894de6aa5678        0         1          0
# 17    016cfd4a-8dd3-4d78-9a08-b6829775f86d        0         1          0
# 2325  f26434d5-e557-4cc8-a0e6-c7ab3d04e09b        0         0          0
# 649   3ff921b4-df67-4c0a-a191-44bf8cba1fb1        0         1          0
# 1938  c8be3fd8-f3fe-4fb3-8c3b-4bf1bfdf382f        0         0          0
# 584   387a1f2d-4bb1-45bc-af27-e140e7366f7e        0         1          0
#
#       flBlueSky  flInstagram  qtdePontos                dtCriacao  \
# 620           0            0           1                      NaN
# ...

# %%
# Atributos de um df
# Quantidade de linhas e colunas
df.shape
# Out:
# (2436, 9)

# %%
# Nomes das colunas
df.columns
# Out:
# Index(['idCliente', 'flEmail', 'flTwitch', 'flYouTube', 'flBlueSky',
#        'flInstagram', 'qtdePontos', 'dtCriacao', 'dtAtualizacao'],
#       dtype='object')

# %%
# Indices
df.index
# Out:
# RangeIndex(start=0, stop=2436, step=1)

# %%
df.dtypes # Retorna uma serie com as colunas e seus tipos
# Out:
# idCliente        object
# flEmail           int64
# flTwitch          int64
# flYouTube         int64
# flBlueSky         int64
# flInstagram       int64
# qtdePontos        int64
# dtCriacao        object
# dtAtualizacao    object
# dtype: object

# %%
file_path2 = '/content/drive/MyDrive/Pandas_2025/data/transacao_produto.csv'
df_trasacoes = pd.read_csv(file_path2)
df_trasacoes.head()
# Out:
#                      idTransacaoProduto                           idTransacao  \
# 0  000026d0-4d4e-4fed-934a-9e5b26d9e379  d59d9859-8fb9-41cc-a296-be38c4dce8e4
# 1  00002f54-dd03-4b3f-ade0-22c3e61df8c2  519241fd-2676-49b2-8e74-0acc09a08f69
# 2  00006a7d-c83a-44ca-aad9-e8a2a2f1b64d  73993c42-d18f-4f51-82c4-25e13c29962c
# 3  00013246-e90f-41a9-b4cc-c9e905fd520b  90bbc76e-f93e-494d-a7ba-5d6e971a88b8
# 4  000146b9-3ecc-4a08-be5a-e8127cf7d9b3  f6efc1f8-4e45-42d2-bb8f-c46fac06a1d5
#
#    idProduto  qtdeProduto  VlProduto
# 0          5            1          1
# 1          5            1          1
# 2         11            1         50
# 3          5            1          1
# 4          5            1          1

# %%
df_trasacoes.shape
# Out:
# (182841, 5)

# %%
df_trasacoes.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182841 entries, 0 to 182840
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   idTransacaoProduto  182841 non-null  object
#  1   idTransacao         182841 non-null  object
#  2   idProduto           182841 non-null  int64
#  3   qtdeProduto         182841 non-null  int64
#  4   VlProduto           182841 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 36.6 MB

# %%
df_trasacoes.dtypes.keys()
# Out:
# Index(['idTransacaoProduto', 'idTransacao', 'idProduto', 'qtdeProduto',
#        'VlProduto'],
#       dtype='object')

# %%
# Renomear colunas == df.rename(columns = {'nome_antigo': 'nome_novo'})
old = list(df_trasacoes.dtypes.keys())
new = ['Id_trans_product', 'Id_trans', 'Id_product', 'Quant_product', 'Value_product']

df_trasacoes.rename(columns=dict(zip(old, new)), inplace=True)
df_trasacoes.head()
# Out:
#                        Id_trans_product                              Id_trans  \
# 0  000026d0-4d4e-4fed-934a-9e5b26d9e379  d59d9859-8fb9-41cc-a296-be38c4dce8e4
# 1  00002f54-dd03-4b3f-ade0-22c3e61df8c2  519241fd-2676-49b2-8e74-0acc09a08f69
# 2  00006a7d-c83a-44ca-aad9-e8a2a2f1b64d  73993c42-d18f-4f51-82c4-25e13c29962c
# 3  00013246-e90f-41a9-b4cc-c9e905fd520b  90bbc76e-f93e-494d-a7ba-5d6e971a88b8
# 4  000146b9-3ecc-4a08-be5a-e8127cf7d9b3  f6efc1f8-4e45-42d2-bb8f-c46fac06a1d5
#
#    Id_product  Quant_product  Value_product
# 0           5              1              1
# 1           5              1              1
# 2          11              1             50
# 3           5              1              1
# 4           5              1              1

# %%
df_trasacoes.get('Id_trans')
# Out:
# 0         d59d9859-8fb9-41cc-a296-be38c4dce8e4
# 1         519241fd-2676-49b2-8e74-0acc09a08f69
# 2         73993c42-d18f-4f51-82c4-25e13c29962c
# 3         90bbc76e-f93e-494d-a7ba-5d6e971a88b8
# 4         f6efc1f8-4e45-42d2-bb8f-c46fac06a1d5
#                           ...
# 182836    02c3bd7e-adf3-4510-b7b8-25df934c1e61
# 182837    30e6ae30-e2b5-46bc-a5c9-a92c4900d548
# 182838    6baf63b1-d05a-419d-a84f-abdf6906fef8
# 182839    90f7149b-5794-4d49-9239-c3bddb5b0980
# 182840    4d7c74c0-5ca0-4786-823b-b393d505c2e6
# Name: Id_trans, Length: 182841, dtype: object

# %%
# Selecionando colunas
colunas = ['Id_trans', 'Id_product', 'Value_product'] # Lista com nomes das colunas que queremos ver
df_trasacoes[colunas]
# Out:
#                                     Id_trans  Id_product  Value_product
# 0       d59d9859-8fb9-41cc-a296-be38c4dce8e4           5              1
# 1       519241fd-2676-49b2-8e74-0acc09a08f69           5              1
# 2       73993c42-d18f-4f51-82c4-25e13c29962c          11             50
# 3       90bbc76e-f93e-494d-a7ba-5d6e971a88b8           5              1
# 4       f6efc1f8-4e45-42d2-bb8f-c46fac06a1d5           5              1
# ...                                      ...         ...            ...
# 182836  02c3bd7e-adf3-4510-b7b8-25df934c1e61           5              1
# 182837  30e6ae30-e2b5-46bc-a5c9-a92c4900d548           5              1
# 182838  6baf63b1-d05a-419d-a84f-abdf6906fef8          11             50
# 182839  90f7149b-5794-4d49-9239-c3bddb5b0980           5              1
# 182840  4d7c74c0-5ca0-4786-823b-b393d505c2e6           5              1
#
# [182841 rows x 3 columns]
